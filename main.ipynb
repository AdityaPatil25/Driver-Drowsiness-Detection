# %%
import cv2 as cv
import tensorflow as tf
from tensorflow.keras.models import load_model
import numpy as np
from pygame import mixer

# %%
face_cascade = cv.CascadeClassifier(cv.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier(cv.data.haarcascades + 'haarcascade_eye.xml')

model = load_model('models//best_model.keras')

# %%
cap = cv.VideoCapture(0)
mixer.init()
sound = mixer.Sound(r'C:\\Users\\itsad\Desktop\\ML projects\Driver Drowziness\\alarm.wav')
Score = 0
while True:
    ret, frame = cap.read()
    height, width = frame.shape[0:2]
    gray = cv.cvtColor(frame,cv.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray,scaleFactor = 1.2, minNeighbors = 3)
    eye  = eye_cascade.detectMultiScale(gray,scaleFactor = 1.2, minNeighbors = 7)

    cv.rectangle(frame,(0,height-50), (200,height), (0,0,0), thickness=cv.FILLED)

    for (x,y,w,h) in faces:
        cv.rectangle(frame, pt1=(x,y), pt2=(x+w,y+h), color=(0,0,255), thickness=4)

    for (ex,ey,ew,eh) in eye:
        #cv.rectangle(frame, pt1 =(ex,ey), pt2=(ex+ew,ey+eh), color = (0,0,255), thickness=2)
        #pre processing
        i = frame[ey:ey+eh, ex:ex+ew]
        i = cv.resize(i,(80,80))
        i = i/255
        i = i.reshape(80,80,3)
        i = np.expand_dims(i,axis=0)

        #prediction
        prediction = model.predict(i)
        
        if prediction[0][0]>0.50:
            cv.putText(frame,'closed',(10,height-20),fontFace=cv.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv.LINE_AA)
            cv.putText(frame,'Score'+str(Score),(100,height-20),fontFace=cv.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv.LINE_AA)
            Score=Score+1
            if(Score>15):
                try:
                    sound.play()
                except:
                    pass
            
        # if eyes are open
        elif prediction[0][1]>0.90:
            cv.putText(frame,'open',(10,height-20),fontFace=cv.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv.LINE_AA)      
            cv.putText(frame,'Score'+str(Score),(100,height-20),fontFace=cv.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv.LINE_AA)
            Score = Score-1
            if (Score<6):
                Score=0


    cv.imshow('frame',frame)
    if(cv.waitKey(33) & 0xFF==ord('d')):
        break

cap.release()
cv.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# ...
